# %%
import numpy as np
import cv2
# loading files 
with_mask=np.load('with_mask.npy')
without_mask=np.load('without_mask.npy')

# %%
with_mask.shape
# Out:
# (200, 50, 50, 3)

# %%
without_mask.shape
# Out:
# (200, 50, 50, 3)

# %%
#converting 4 dimension data into 2 dimensional data 
with_mask=with_mask.reshape(200,50*50 * 3)

# %%
without_mask=without_mask.reshape(200,50*50 * 3)

# %%
with_mask.shape
without_mask.shape
# Out:
# (200, 7500)

# %%
#concatinatin rows 
X=np.r_[with_mask,without_mask]
X.shape
# Out:
# (400, 7500)

# %%
#first 200 images will be zeros(0) that will pointing to with mask data
# and the next 200 images will be (1.0) pointing to without mask


labels= np.zeros(X.shape[0])
labels[200:]=1.0

names={0:"Mask",1:"No Mask"}

# %%
#machine learning algorithm 
#svm - support vector machine 
#SVC - support Vector Classifcation
from sklearn.svm import SVC

#accuracy measurement
from sklearn.metrics import accuracy_score

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test =  train_test_split(X, labels, test_size=0.25)

# %%
x_train.shape
# Out:
# (300, 7500)

# %%
#dimensionality reduction
from sklearn.decomposition import PCA # principal component analysis
pca=PCA(n_components=3) #converting from 7500 to 3 dimensional
x_train=pca.fit_transform(x_train)
x_train[0]
# Out:
# array([-1074.82694128, -2189.71810434,   892.51237353])

# %%
x_train.shape
# Out:
# (300, 3)

# %%
svm = SVC()
svm.fit(x_train, y_train)
# Out:
# SVC()

# %%
x_test = pca.transform(x_test)
y_pred = svm.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\MACHINE LEARNING\detectingmaskml.ipynb Cell 17' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/MACHINE%20LEARNING/detectingmaskml.ipynb#ch0000021?line=0'>1</a> x_test = pca.transform(x_test)
#       <a href='vscode-notebook-cell:/d%3A/MACHINE%20LEARNING/detectingmaskml.ipynb#ch0000021?line=1'>2</a> y_pred = svm.predict(x_test)
#
# File c:\Users\ishan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\decomposition\_base.py:120, in _BasePCA.transform(self, X)
#     <a href='file:///c%3A/Users/ishan/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/decomposition/_base.py?line=100'>101</a> """Apply dimensionality reduction to X.
#     <a href='file:///c%3A/Users/ishan/AppData/Local/Programs/Python/Python310/lib/site-packages/sklearn/decomposition/_base.py?line=101'>102</a>
# ...

# %%
accuracy_score(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\MACHINE LEARNING\detectingmaskml.ipynb Cell 17' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/MACHINE%20LEARNING/detectingmaskml.ipynb#ch0000017?line=0'>1</a> accuracy_score(y_test, y_pred)
#
# NameError: name 'y_pred' is not defined

# %%
# haar_data = cv2.CascadeClassifier('D:\\MACHINE LEARNING\\haar_data\\haarcascade_frontface.xml')
# capture=cv2.VideoCapture(0)
# data=[]
# font=cv2.FONT_HERSHEY_COMPLEX
# font = cv2.Font_Hershey_Complex
# while True:
#     flag, img = capture.read()
#     if flag:
#         faces = haar_data.detectMultiscale(img)
#         for x,y,w,h in faces:
#             cv2.rectangle(img,(x,y),(x+w,y+h), (255,0,255),4)
#             #number of rows and height and the 3rd dimension
# 		    face = img[y:y+h, x:x+w,  :]
# 		    face=cv2.resize(face,(50,50))  #equalizing all faces 
# 		    face=face.reshape(1,-1)
# 			# face=pca.transform(face)
# 			pred =svm.predict(face)[0]
# 			n=names[int(pred)]
# 			cv2.putText(img, n,(x,y), font, 1,(244,250,250),2)
# 			print(n)
#         cv2.imshow('result',img)
#         if cv2.waitKey(2)==27 :
#             break
# capture.release()
# cv2.destroyAllWindows()

# %%
haar_data = cv2.CascadeClassifier('D:\\MACHINE LEARNING\\haar_data\\haarcascade_frontface.xml')
capture=cv2.VideoCapture(0)
data=[]
font=cv2.FONT_HERSHEY_COMPLEX
while True:
    flag, img = capture.read()
    if flag:
        faces=haar_data.detectMultiScale(img)
        for x,y,w,h in faces:
            cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,255),4)
            face = img[y:y+h, x:x+w, :] #adding three dimensions (height, width and 3rd)
            face=cv2.resize(face,(50,50)) #equalizing alL faces
            face=face.reshape(1,-1)
            face=pca.transform(face)
            pred =svm.predict(face)[0]
            n=names[int(pred)]
            
            cv2.putText(img, n,(x,y), font, 1,(244,250,250),2)
            print(n)
        cv2.imshow('result',img)
        if cv2.waitKey(2)==27: #27 is the ASCII value for ESC
            break
capture.release()
cv2.destroyAllWindows()
# Out:
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# ...
